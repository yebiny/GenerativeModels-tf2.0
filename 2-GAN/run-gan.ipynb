# %%
IMG_SHAPE= (28,28,1)
NOISE_DIM = 100

# %%
from data_generator import *

x_train, y_train = get_fashion_mnist()
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28, 1), (60000, 10))

# %%
from build_models import *

builder = BuildModels(IMG_SHAPE, NOISE_DIM)
gene = builder.build_generator()
disc = builder.build_discriminator()

# %%
from gan import *
model = GAN(gene, disc, IMG_SHAPE, NOISE_DIM)
model.compile()
model.gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_noise (InputLayer)     [(None, 100)]             0
# _________________________________________________________________
# G (Model)                    (None, 28, 28, 1)         840705
# _________________________________________________________________
# D (Model)                    (None, 1)                 212865
# =================================================================
# Total params: 1,053,570
# Trainable params: 840,321
# Non-trainable params: 213,249
# _________________________________________________________________

# %%
history = model.train(x_train, epochs=5)
# Out:
# * epoch: 1, d_loss: 2167.353641, g_loss: 3997.001737
# * epoch: 2, d_loss: 2289.350582, g_loss: 3659.624046
# * epoch: 3, d_loss: 2241.491296, g_loss: 3814.409895
# * epoch: 4, d_loss: 2187.894053, g_loss: 4050.346668
# * epoch: 5, d_loss: 2182.439611, g_loss: 4131.068136

# %%
history
# Out:
# {'d_loss': [2167.3536405675113,
#   2289.350581794977,
#   2241.491296224296,
#   2187.89405323565,
#   2182.4396111518145],
#  'g_loss': [3997.001736998558,
#   3659.6240462064743,
#   3814.40989536047,
#   4050.3466683626175,
#   4131.068136155605]}
