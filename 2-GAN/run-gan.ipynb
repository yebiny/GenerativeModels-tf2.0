# %%
IMG_SHAPE= (28,28,1)
NOISE_DIM = 100

# %%
from data_generator import *

x_train, y_train = get_fashion_mnist()
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28, 1), (60000, 10))

# %%
from build_models import *

builder = BuildModels(IMG_SHAPE, NOISE_DIM)
gene = builder.build_generator()
disc = builder.build_discriminator()

# %%
from gan import *
model = GAN(gene, disc, IMG_SHAPE, NOISE_DIM)
model.compile()
model.gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_noise (InputLayer)     [(None, 100)]             0
# _________________________________________________________________
# G (Model)                    (None, 28, 28, 1)         840705
# _________________________________________________________________
# D (Model)                    (None, 1)                 212865
# =================================================================
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Total params: 840,705
# Trainable params: 840,321
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.train(x_train, epochs=5)
# Out:
# * epoch: 1, d_loss: 2115.184371, g_loss: 4194.912923
# * epoch: 2, d_loss: 2227.475208, g_loss: 3906.613178
# * epoch: 3, d_loss: 2235.965324, g_loss: 3849.009120
# * epoch: 4, d_loss: 2190.128334, g_loss: 4051.759586
# * epoch: 5, d_loss: 2159.699729, g_loss: 4198.237896

# %%
history
# Out:
# {'d_loss': [2115.184370804578,
#   2227.4752084314823,
#   2235.965324267745,
#   2190.128334015608,
#   2159.6997294425964],
#  'g_loss': [4194.912922501564,
#   3906.613178253174,
#   3849.009119808674,
#   4051.7595863342285,
#   4198.237895548344]}
